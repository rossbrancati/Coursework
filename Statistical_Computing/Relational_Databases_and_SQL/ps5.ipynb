# %% [markdown]
# # Problem Set 5

# %%
import sqlite3
import pandas as pd
import numpy as np
import seaborn as sns
import pdb

# %% [markdown]
# ## Problem A: Writing queries
# Make a connection to the baseball sqlite database and create a cursor object on the database.
# Name the connection `conn` and the cursor `c`.

# %%
#IMPLEMENT ME (2 lines)
conn=sqlite3.connect("baseball.db")
c = conn.cursor()

# %% [markdown]
# The following prints the names of all of the tables in the database.

# %%
c.execute("SELECT name FROM sqlite_master where type='table'")
for name in c.fetchall():
    print(name[0])
# Out:
# Master
# sqlite_sequence
# Teams
# TeamsFranchises
# TeamsHalf
# Batting
# Pitching
# Fielding
# FieldingOF
# Salaries
# Managers
# ManagersHalf
# AllstarFull
# AwardsPlayers
# AwardsSharePlayers
# AwardsManagers
# AwardsShareManagers
# HallOfFame
# BattingPost
# FieldingPost
# PitchingPost
# SeriesPost
# Schools
# SchoolsPlayers
# xref_stats
# Appearances

# %% [markdown]
# ### Part 2
# Print the column names for the Salaries table.

# %%
# IMPLEMENT ME; save column names as a list under 'names' to print
c.execute("SELECT * From Salaries")
names = [description[0] for description in c.description]
# Don't modify anything below.
print(names)
# Out:
# ['yearID', 'teamID', 'lgID', 'playerID', 'salary']

# %% [markdown]
# ### Part 3
# Print the first ten records in the Salaries table using `fetchmany`.

# %%
# IMPLEMENT ME; save first ten records as a list under 'recordsA' using fetchmany to print
c.execute("SELECT * From Salaries")
recordsA = c.fetchmany(10)
# Don't modify anything below
for i in recordsA:
    print(i)
# Out:
# (1980, 'TOR', 'AL', 'stiebda01', 55000.0)
# (1981, 'NYA', 'AL', 'jacksre01', 588000.0)
# (1981, 'TOR', 'AL', 'stiebda01', 85000.0)
# (1982, 'TOR', 'AL', 'stiebda01', 250000.0)
# (1983, 'TOR', 'AL', 'stiebda01', 450000.0)
# (1984, 'TOR', 'AL', 'stiebda01', 650000.0)
# (1985, 'ATL', 'NL', 'barkele01', 870000.0)
# (1985, 'ATL', 'NL', 'bedrost01', 550000.0)
# (1985, 'ATL', 'NL', 'benedbr01', 545000.0)
# (1985, 'ATL', 'NL', 'campri01', 633333.0)

# %% [markdown]
# ## Problem B: Grouping and Sorting
# ### Part 1
# Write an execute statement on cursor `c` that selects the average salary tuples for 2010 grouped by teamID. You should pass year `y` into the statement as a variable for safety.

# %%
y = ('2010',)
# IMPLEMENT ME
c.execute("SELECT teamID, AVG(salary) From Salaries WHERE yearID = ? GROUP BY teamID", y)
recordsB1 = c.fetchall()
for r in recordsB1:
    print((r[0], r[1]))
# Out:
# ('ARI', 2335314.076923077)
# ('ATL', 3126802.4444444445)
# ('BAL', 3138942.3076923075)
# ('BOS', 5601632.172413793)
# ('CHA', 4058846.153846154)
# ('CHN', 5429962.962962963)
# ('CIN', 2760059.3076923075)
# ('CLE', 2110481.5862068967)
# ('COL', 2904379.3103448274)
# ('DET', 4550552.888888889)
# ('FLO', 2112211.814814815)
# ('HOU', 3298410.714285714)
# ('KCA', 2644637.407407407)
# ('LAA', 3619443.6551724137)
# ('LAN', 3531778.3703703703)
# ('MIL', 2796837.172413793)
# ('MIN', 3484255.9285714286)
# ('NYA', 8253335.56)
# ('NYN', 4800819.357142857)
# ('OAK', 1726715.625)
# ('PHI', 5068870.678571428)
# ('PIT', 1294185.1851851852)
# ('SDN', 1453819.2307692308)
# ('SEA', 3089642.8571428573)
# ('SFN', 3522904.75)
# ('SLN', 3741630.04)
# ('TBA', 2663832.2592592593)
# ('TEX', 1905191.1724137932)
# ('TOR', 2074466.6666666667)
# ('WAS', 2046666.6666666667)

# %% [markdown]
# ### Part 2
# Print the playerID and salary for the player with this highest salary in 2010. Make the year a variable in your execute statement.

# %%
# IMPLEMENT ME; save all records as a list under 'recordsB2' to print
c.execute("SELECT playerID, MAX(salary) From Salaries WHERE yearID = ?", y)
recordsB2 = c.fetchall()
# Don't modify anything below
for r in recordsB2:
    print((r[0], r[1]))
# Out:
# ('rodrial01', 33000000.0)

# %% [markdown]
# ### Part 3
# Print the teamID and total salary for each team in 2010. Sort by descending total salary. Make the year a variable in your execute statement.

# %%
# IMPLEMENT ME; save all records as a list under 'recordsB3' to print
c.execute("SELECT teamID, SUM(salary) FROM Salaries WHERE yearID = ? GROUP BY teamID ORDER BY SUM(salary) DESC", y)
recordsB3 = c.fetchall()
# Don't modify anything below
for r in recordsB3:
    print((r[0], r[1]))
# Out:
# ('NYA', 206333389.0)
# ('BOS', 162447333.0)
# ('CHN', 146609000.0)
# ('PHI', 141928379.0)
# ('NYN', 134422942.0)
# ('DET', 122864928.0)
# ('CHA', 105530000.0)
# ('LAA', 104963866.0)
# ('SFN', 98641333.0)
# ('MIN', 97559166.0)
# ('LAN', 95358016.0)
# ('SLN', 93540751.0)
# ('HOU', 92355500.0)
# ('SEA', 86510000.0)
# ('ATL', 84423666.0)
# ('COL', 84227000.0)
# ('BAL', 81612500.0)
# ('MIL', 81108278.0)
# ('TBA', 71923471.0)
# ('CIN', 71761542.0)
# ('KCA', 71405210.0)
# ('TOR', 62234000.0)
# ('WAS', 61400000.0)
# ('CLE', 61203966.0)
# ('ARI', 60718166.0)
# ('FLO', 57029719.0)
# ('OAK', 55254900.0)
# ('TEX', 55250544.0)
# ('SDN', 37799300.0)
# ('PIT', 34943000.0)

# %%
#Important to close the connection to the database
conn.close()

# %% [markdown]
# ## Problem C: Using pandas to get the results of a query

# %% [markdown]
# ### Part 1
# 1. Make a new connection to the baseball database.
# 2. Read the table names into a pandas data frame.
# 3. Read the Salaries table into a pandas data frame.
# 4. Using `head()` print the top records in the Salaries table.

# %%
# IMPLEMENT ME (4 lines including the line given below)
#make new connection to baseball database
conn_2=sqlite3.connect("baseball.db")
#read table names into pandas dataframe
df_table_names = pd.read_sql_query("SELECT name FROM sqlite_master where type='table'", conn_2)
#read salaries table into pandas dataframe
df_Salaries = pd.read_sql_query("SELECT * FROM Salaries", conn_2)
#print the top records for Salaries table
df_Salaries.head()
# Out:
#    yearID teamID lgID   playerID    salary
# 0    1980    TOR   AL  stiebda01   55000.0
# 1    1981    NYA   AL  jacksre01  588000.0
# 2    1981    TOR   AL  stiebda01   85000.0
# 3    1982    TOR   AL  stiebda01  250000.0
# 4    1983    TOR   AL  stiebda01  450000.0

# %% [markdown]
# ### Part 2
# 1. Create a new data frame with only the 2010 salaries
# 2. Extract the tuple for the player with the highest salary in 2010.
# 3. Print the tuple.

# %%
# IMPLEMENT ME (2 lines); save the tuple under 'highest_salary_2010'
df_2010_Salaries = pd.read_sql_query("SELECT * FROM Salaries where yearID=2010", conn_2)
highest_salary_2010 = df_2010_Salaries.loc[df_2010_Salaries['salary'] == max(df_2010_Salaries['salary'])]
# Don't modify anything below
print(highest_salary_2010)
# Out:
#      yearID teamID lgID   playerID      salary
# 485    2010    NYA   AL  rodrial01  33000000.0

# %% [markdown]
# ### Part 3
# Use `groupby` and `agg` for extract the total salary grouped by team in the 2010 salary data frame. Print the head of the data frame.

# %%
# IMPLEMENT ME (2 lines); save the dataframe under 'df_groupby'
#group by the teamID, and calculate the sum of the salary
df_groupby = df_2010_Salaries.groupby(['teamID']).sum()
#remove the yearID 
df_groupby = df_groupby.drop(columns=["yearID"])
#display the head of the data frame
df_groupby.head()
# Out:
#              salary
# teamID
# ARI      60718166.0
# ATL      84423666.0
# BAL      81612500.0
# BOS     162447333.0
# CHA     105530000.0

# %% [markdown]
# ## Problem D: Joining tables in pandas

# %% [markdown]
# ### Part 1
# 1. Import the Master table into a pandas dataframe. Show the head lines using `head`.

# %%
# IMPLEMENT ME
df_Master = pd.read_sql_query("SELECT * FROM Master", conn_2)
df_Master.head()
# Out:
#    lahmanID   playerID managerID       hofID  birthYear  birthMonth  birthDay  \
# 0         1  aaronha01            aaronha01h     1934.0         2.0       5.0
# 1         2  aaronto01                           1939.0         8.0       5.0
# 2         3   aasedo01                           1954.0         9.0       8.0
# 3         4   abadan01                           1972.0         8.0      25.0
# 4         5  abadijo01                           1854.0        11.0       4.0
#
#   birthCountry birthState        birthCity  ...  bats  throws       debut  \
# 0          USA         AL           Mobile  ...     R       R  1954-04-13
# 1          USA         AL           Mobile  ...     R       R  1962-04-10
# 2          USA         CA           Orange  ...     R       R  1977-07-26
# 3          USA         FL  West Palm Beach  ...     L       L  2001-09-10
# 4          USA         PA     Philadelphia  ...     R       R  1875-04-26
#
#     finalGame            college lahman40ID lahman45ID   retroID    holtzID  \
# 0  1976-10-03                     aaronha01  aaronha01  aaroh101  aaronha01
# 1  1971-09-26                     aaronto01  aaronto01  aarot101  aaronto01
# 2  1990-10-03  Cal St. Fullerton   aasedo01   aasedo01  aased001   aasedo01
# 3  2006-04-13  Middle Georgia JC   abadan01   abadan01  abada001   abadan01
# 4  1875-06-10                     abadijo01  abadijo01  abadj101  abadijo01
#
#      bbrefID
# 0  aaronha01
# 1  aaronto01
# 2   aasedo01
# 3   abadan01
# 4  abadijo01
#
# [5 rows x 33 columns]

# %% [markdown]
# 2. Import the Teams table into a pandas dataframe. Show the head lines using `head`.

# %%
# IMPLEMENT ME
df_Teams = pd.read_sql_query("SELECT * FROM Teams", conn_2)
df_Teams.head()
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L  ...  DP     FP  \
# 0    1871   NA    BS1      BNA  None     3  31    NaN  20  10  ... NaN  0.838
# 1    1871   NA    CH1      CNA  None     2  28    NaN  19   9  ... NaN  0.829
# 2    1871   NA    CL1      CFC  None     8  29    NaN  10  19  ... NaN  0.814
# 3    1871   NA    FW1      KEK  None     7  19    NaN   7  12  ... NaN  0.803
# 4    1871   NA    NY2      NNA  None     5  33    NaN  16  17  ... NaN  0.839
#
#                       name                          park  attendance  BPF  \
# 0     Boston Red Stockings           South End Grounds I         NaN  103
# 1  Chicago White Stockings       Union Base-Ball Grounds         NaN  104
# 2   Cleveland Forest Citys  National Association Grounds         NaN   96
# 3     Fort Wayne Kekiongas                Hamilton Field         NaN  101
# 4         New York Mutuals      Union Grounds (Brooklyn)         NaN   90
#
#    PPF  teamIDBR  teamIDlahman45  teamIDretro
# 0   98       BOS             BS1          BS1
# 1  102       CHI             CH1          CH1
# 2  100       CLE             CL1          CL1
# 3  107       KEK             FW1          FW1
# 4   88       NYU             NY2          NY2
#
# [5 rows x 48 columns]

# %% [markdown]
# ### Part 2
# Using a left merge, combine the Salaries table with the Teams table on the teamID and yearID key retaining all of the records in Salaries.

# %%
df_merge1 = pd.merge(df_Salaries, df_Teams, on=['teamID', 'yearID'], how='left') # IMPLEMENT ME
#df_merge1.head()

# %% [markdown]
# ### Part 3
# Merge the previous data frame with the Master table on playerID retaining all of the salary rows. Show the head lines using `head`.

# %%
df_merge2 = pd.merge(df_merge1, df_Master, on=['playerID'], how='outer') # IMPLEMENT ME
# IMPLEMENT ME; show the head lines
df_merge2.head()
# Out:
#    yearID teamID lgID_x   playerID    salary lgID_y franchID divID  Rank  \
# 0  1980.0    TOR     AL  stiebda01   55000.0     AL      TOR     E   7.0
# 1  1981.0    TOR     AL  stiebda01   85000.0     AL      TOR     E   7.0
# 2  1982.0    TOR     AL  stiebda01  250000.0     AL      TOR     E   6.0
# 3  1983.0    TOR     AL  stiebda01  450000.0     AL      TOR     E   4.0
# 4  1984.0    TOR     AL  stiebda01  650000.0     AL      TOR     E   2.0
#
#        G  ...  bats  throws       debut   finalGame            college  \
# 0  162.0  ...     R       R  1979-06-29  1998-09-25  Southern Illinois
# 1  106.0  ...     R       R  1979-06-29  1998-09-25  Southern Illinois
# 2  162.0  ...     R       R  1979-06-29  1998-09-25  Southern Illinois
# 3  162.0  ...     R       R  1979-06-29  1998-09-25  Southern Illinois
# 4  163.0  ...     R       R  1979-06-29  1998-09-25  Southern Illinois
#
#   lahman40ID lahman45ID   retroID    holtzID    bbrefID
# 0  stiebda01  stiebda01  stied001  stiebda01  stiebda01
# 1  stiebda01  stiebda01  stied001  stiebda01  stiebda01
# 2  stiebda01  stiebda01  stied001  stiebda01  stiebda01
# 3  stiebda01  stiebda01  stied001  stiebda01  stiebda01
# 4  stiebda01  stiebda01  stied001  stiebda01  stiebda01
#
# [5 rows x 83 columns]

# %% [markdown]
# ### Part 4
# Print the head records with the following columns from the resulting data frame: first name, last name, team name, year, salary.

# %%
# IMPLEMENT ME
#print all column names to pull needed columns
#print(df_merge2.columns)
#create final data frame with the necessay columns
final_df = df_merge2[["nameFirst","nameLast","teamID","yearID","salary"]]
#display header of new dataframe
final_df.head()
# Out:
#   nameFirst nameLast teamID  yearID    salary
# 0      Dave    Stieb    TOR  1980.0   55000.0
# 1      Dave    Stieb    TOR  1981.0   85000.0
# 2      Dave    Stieb    TOR  1982.0  250000.0
# 3      Dave    Stieb    TOR  1983.0  450000.0
# 4      Dave    Stieb    TOR  1984.0  650000.0

# %%
#Important to close the connection to the database
conn_2.close()
